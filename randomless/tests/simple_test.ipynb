# %%
from randomless import Random
random = Random()
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
rc={'lines.linewidth': 2, 'axes.labelsize': 18, 'axes.titlesize': 18}
sns.set(rc=rc)
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
np.array([random.random() for i in range(10)])
# Out:
# array([0.95052784, 0.44378246, 0.914501  , 0.22092525, 0.61198475,
#        0.10658327, 0.65493128, 0.83425166, 0.01935473, 0.80200742])

# %%
x = np.sort(np.array([random.random() for i in range(100000)]))
y = np.arange(1, len(x)+1) / len(x)
plt.plot(x[::1000], y[::1000], marker='.', linestyle='none', markersize=10)
